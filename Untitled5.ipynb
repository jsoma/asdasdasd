# %%
import pandas as pd

df = pd.DataFrame([
    {'year': '2016', 'value': 4},
    {'year': '2016', 'value': 6},
    {'year': '2017', 'value': 8},
    {'year': '2017', 'value': 10},
])
df
# Out:
#    year  value
# 0  2016      4
# 1  2016      6
# 2  2017      8
# 3  2017     10

# %%
df_2016 = df[df.year == '2016']
df_2016
# Out:
#    year  value
# 0  2016      4
# 1  2016      6

# %%
df_2016['year_int'] = df_2016.year.astype(int)
df_2016
# Out:
# /var/folders/l0/h__2c37508b8pl19zp232ycr0000gn/T/ipykernel_31405/2532518345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2016['year_int'] = df_2016.year.astype(int)
#    year  value  year_int
# 0  2016      4      2016
# 1  2016      6      2016

# %%
df
# Out:
#    year  value
# 0  2016      4
# 1  2016      6
# 2  2017      8
# 3  2017     10

# %%
df.loc[df.year == '2016', 'year_int'] = 2016

# %%
df
# Out:
#    year  value  year_int
# 0  2016      4    2016.0
# 1  2016      6    2016.0
# 2  2017      8       NaN
# 3  2017     10       NaN

# %%
df_2016
# Out:
#    year  value  year_int
# 0  2016      4      2016
# 1  2016      6      2016

# %%
df_2016 = df.loc[df.year == '2016']
df_2016
# Out:
#    year  value  year_int
# 0  2016      4    2016.0
# 1  2016      6    2016.0

# %%
df_2016['year_int'] = 2017
# Out:
# /var/folders/l0/h__2c37508b8pl19zp232ycr0000gn/T/ipykernel_31405/3790576059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2016['year_int'] = 2017

# %%
for i in range(2000):
    print("Scraping another page")
# Out:
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# Scraping another page
# ...
